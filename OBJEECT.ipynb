# %%
conda install numpy
# Out:
# ...
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c intel mkl
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\marin\Anaconda3
#
#   added / updated specs:
#     - mkl
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2021.10.8          |   py39haa95532_2         156 KB  intel
#     openssl-1.1.1n             |       h2bbff1b_0         5.8 MB  intel
#     ------------------------------------------------------------
#                                            Total:         5.9 MB
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   certifi                                         pkgs/main --> intel
#   openssl                                         pkgs/main --> intel
#
#
#
# ...
#
# certifi-2021.10.8    | 156 KB    |            |   0%
# certifi-2021.10.8    | 156 KB    | #          |  10%
# certifi-2021.10.8    | 156 KB    | ##         |  20%
# ...

# %%
pip --default-timeout=1200 install pyside2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install torch==1.8.1+cu111 torchvision==0.9.1+cu111 torchaudio===0.8.1 -f https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# Out:
# Looking in links: https://download.pytorch.org/whl/lts/1.8/torch_lts.html
# ...

# %%
# !cd yolov5 & pip install -r requirements.txt

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s')
# Out:
# Using cache found in C:\Users\marin/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2022-5-12 torch 1.8.1+cu111 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.5 GFLOPs
# Adding AutoShape...

# %%
img = 'https://i.guim.co.uk/img/media/f55d0f5b81e308066b23cdc52a2e371d6be4e295/0_188_6000_3600/master/6000.jpg?width=1200&height=1200&quality=85&auto=format&fit=crop&s=b232a01559f2412518e2d2c8832633ba'

# %%
results = model(img)
results.print()
# Out:
# image 1/1: 1200x1200 1 person, 1 bicycle
# Speed: 664.5ms pre-process, 407.1ms inference, 0.0ms NMS per image at shape (1, 3, 640, 640)

# %%
# %matplotlib inline 
plt.imshow(np.squeeze(results.render()))
plt.show()

# %%
results.show()
